# %%
import seaborn as sns

# %%
#Strip Plot
tips=sns.load_dataset('tips')

# %%
#Axes level
sns.stripplot(tips,x='day',y='total_bill',jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='strip')

# %%
sns.catplot(data=tips,x='day',y='total_bill',
           jitter=0.2,hue='sex')

# %%
sns.catplot(tips,x='day',y='total_bill',kind='swarm')

# %%
sns.swarmplot(tips,x='day',y='total_bill',hue='sex')
#add distribution (small size)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Distribution Categorical(boxplot),(violinplot)

# %%
sns.catplot(data=tips,x='total_bill',y='day',kind='box')

# %%
sns.boxplot(data=tips,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
## Violen Plot (Box+KDE)
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,kind='violin',hue='sex',x='day',y='total_bill',split=True)

# %% [markdown]
# ## Categorical Distribution plots

# %%
#barplot
sns.barplot(tips,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(tips,x='sex',y='total_bill',hue='smoker',estimator=np.max)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#pointplot
sns.pointplot(tips,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#countplot
sns.countplot(tips,x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(tips,x='day',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#faceting
sns.catplot(tips,x='sex',y='total_bill',col='smoker',kind='bar',row='time')

# %%
sns.regplot(data=tips,x='total_bill',y='tip',color='lightblue')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
#residplot(residual plots for normality of errors)
sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(data=tips,markers='*')

# %% [markdown]
# ## FacetGrid(rel,dis,cat,lm)(figure level)

# %%
sns.catplot(data=tips,x='sex',y='tip',kind='violin',col='day',row='time')

# %%
g=sns.FacetGrid(data=tips,row='time',col='day')
g.map(sns.violinplot,'sex','total_bill')
# Out:
# C:\Users\swaya\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(data=tips,row='time',col='day')
g.map(sns.boxplot,'sex','total_bill')
# Out:
# C:\Users\swaya\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
iris=sns.load_dataset('iris')
sns.pairplot(iris,hue='species')

# %% [markdown]
# ## PairGrid

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.boxplot)
g.map_offdiag(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.boxplot)
g.map_offdiag(sns.histplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.kdeplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

# %%
g=sns.PairGrid(data=iris,hue='species',vars=['sepal_width','petal_width'])
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
plt.savefig('correlationplot.jpg')

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hist')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='reg')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hex')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='resid')

# %%
g=sns.JointGrid(data=tips[['total_bill','tip']])
g.plot(sns.scatterplot,sns.histplot)

# %%
g=sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.violinplot)

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
