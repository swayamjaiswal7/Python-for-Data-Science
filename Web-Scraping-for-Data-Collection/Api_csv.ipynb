# %% [markdown]
# ## What is an API?
# An API is a set of rules and protocols that allow different software applications to communicate with each other. APIs define the methods and data formats that applications can use to request and exchange information, enabling developers to leverage existing services and data sources instead of building everything from scratch.

# %% [markdown]
# ## Types of APIs
# There are several types of APIs, including:
#
# REST (Representational State Transfer): A popular architectural style for designing networked applications. RESTful APIs use standard HTTP methods (GET, POST, PUT, DELETE) and are typically used for web services.
# SOAP (Simple Object Access Protocol): An older protocol for exchanging structured information in web services. SOAP uses XML for message formatting and relies on a set of rules for message structure.
# GraphQL: A query language for APIs developed by Facebook, allowing clients to request exactly the data they need, making it more efficient than REST in some scenarios.

# %% [markdown]
# ## How to Fetch Data from an API
# Fetching data from an API typically involves making an HTTP request to a specific endpoint and processing the response. Here’s a step-by-step guide to fetching data from a RESTful API using Python.

# %% [markdown]
# ## Step 1: Understand the API Documentation
# Before you start coding, it’s essential to understand the API you’re working with. Most APIs provide documentation that explains the available endpoints, request parameters, authentication methods, and response formats. Take the time to read through the documentation to familiarize yourself with the API.
# ###
#
# Step 2: Set Up Your Development Environment
# To fetch data from an API, you’ll need a development environment with Python installed. You’ll also need a library to make HTTP requests. In this example, we’ll use the requests library, which is popular for its simplicity and ease of use.
#
# Install Python: If you don’t have Python installed, download and install it from python.org.
# Install the requests Library: You can install the requests library using pip.
# pip install r### equests
# Step 3: Write the Code
# Create a new Python file, e.g., fetch_data.py, and add the following code:
#
# import requests
# response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=256da2d742d5a5979790e6833447e4b4').json()
# Popularity = []
# Vote_count = []
# Orignal_lang = []
# Title = []
# Vote_avg = []
# Overview = []
# Release_Data = []
#
# for i in response['results']:
#     Popularity.append(i['popularity'])
#     Vote_count.append(i['vote_count'])
#     Orignal_lang.append(i['original_language'])
#     Title.append(i['title'])
#     Vote_avg.append(i['vote_average'])
#     Overview.append(i['overview'])
#     Release_Data.append(i['release_date'])
#
# d = {'title':Title,'Overview':Overview,'Orignal_lang':Orignal_lang,'Release_Data':R

# %% [markdown]
# ### Explanation
# This code snippet does the following:
#
# Imports the requests Library: We use the requests library to make HTTP requests.
# Defines the API Endpoint: We specify the URL of the API endpoint we want to fetch data from.
# Creates Variables to Store Data: We initialize empty lists to store the data we fetch from the API response.
# Processes the Response: We loop through the results in the API response and append the relevant data to our lists.
# Creates a Dictionary to Organize Data: We combine our lists into a dictionary for easier acc ss and manipu
#
#  ation.
# Best Practices for Fetching Data from APIs
# Handle Errors Gracefully: Always include error handling to manage network issues, invalid responses, or other unexpected conditions.
# Use Environment Variables: Store sensitive information, such as API keys and secrets, in environment variables to keep them secure.
# Respect Rate Limits: Many APIs impose rate limits to prevent abuse. Be mindful of these limits and implement appropriate throttling in your code.
# Cache Responses: To improve performance and reduce the number of requests, consider caching API responses when appropriate.
# Use Pagination: When dealing with large datasets, use pagination to fetch data in smaller chunks, rather than retrieving everything in a single request.
# Keep Your Code Modular: Organize your code into reusable modules to make it easier to maintain and extend.

# %%
import requests
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=256da2d742d5a5979790e6833447e4b4').json()
#importing and defining API endpoint
Popularity = []
Vote_count = []
Orignal_lang = []#storing the data from API response
Title = []
Vote_avg = []
Overview = []
Release_Data = []

# %%
for i in response['results']:#loop through the results in API response and append data to list then convert into dictionary
    Popularity.append(i['popularity'])
    Vote_count.append(i['vote_count'])
    Orignal_lang.append(i['original_language'])
    Title.append(i['title'])
    Vote_avg.append(i['vote_average'])
    Overview.append(i['overview'])
    Release_Data.append(i['release_date'])

d = {'title':Title,'Overview':Overview,'Orignal_lang':Orignal_lang,'Release_Data':Release_Data,'Popularity':Popularity,'Vote_count':Vote_count,'Vote_avg':Vote_avg}

# %%
d
# Out:
# {'title': ['A Working Man',
#   'A Minecraft Movie',
#   'In the Lost Lands',
#   'Bullet Train Explosion',
#   'The Siege',
#   'Havoc',
#   'Sinners',
#   'Captain America: Brave New World',
#   'G20',
#   'Novocaine',
#   'Conclave',
#   'Ash',
#   'Gunslingers',
#   'The Woman in the Yard',
#   'Locked',
#   'Moana 2',
#   'Sonic the Hedgehog 3',
#   'Mufasa: The Lion King',
#   'Laila',
#   'Avengers: Infinity War',
#   'A Working Man',
#   'A Minecraft Movie',
#   'In the Lost Lands',
#   'Bullet Train Explosion',
#   'The Siege',
#   'Havoc',
#   'Sinners',
#   'Captain America: Brave New World',
#   'G20',
#   'Novocaine',
#   'Conclave',
#   'Ash',
#   'Gunslingers',
#   'The Woman in the Yard',
#   'Locked',
#   'Moana 2',
#   'Sonic the Hedgehog 3',
#   'Mufasa: The Lion King',
#   'Laila',
#   'Avengers: Infinity War'],
# ...

# %%
import pandas as pd
df=pd.DataFrame(d)

# %%
df.head()
# Out:
#                     title                                           Overview  ... Vote_count Vote_avg
# 0           A Working Man  Levon Cade left behind a decorated military ca...  ...        436    6.297
# 1       A Minecraft Movie  Four misfits find themselves struggling with o...  ...        728    6.200
# 2       In the Lost Lands  A queen sends the powerful and feared sorceres...  ...        288    6.292
# 3  Bullet Train Explosion  When panic erupts on a Tokyo-bound bullet trai...  ...         55    6.400
# 4               The Siege  International assassin Walker is compromised d...  ...         39    5.333
#
# [5 rows x 7 columns]

# %%
df.describe()
# Out:
#        Popularity   Vote_count   Vote_avg
# count   40.000000     40.00000  40.000000
# mean   260.156325   2214.05000   6.582750
# std    155.819678   6613.97078   0.800252
# min    130.589900      3.00000   5.000000
# 25%    154.016650     83.75000   6.133250
# 50%    204.157400    380.50000   6.514500
# 75%    303.826750   1722.75000   7.110250
# max    740.095300  30450.00000   8.235000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         40 non-null     object
#  1   Overview      40 non-null     object
#  2   Orignal_lang  40 non-null     object
#  3   Release_Data  40 non-null     object
#  4   Popularity    40 non-null     float64
#  5   Vote_count    40 non-null     int64
#  6   Vote_avg      40 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.3+ KB

# %%
df.to_csv('Imdb_Movies_dataset.csv')

# %%
#Example 2
import json

# %% [markdown]
# In this Python program fetches the live stock data for "IBM" from the Alpha Vantage API using the 5-minute interval and prints the opening price.Here we make use of 'requests' to make a call and it is checked with the help of status code that whether our request was successful or not.Then the response is converted to python dictionary and the respected data is stored .

# %%
def get_stock():
    '''This function fetches the API data from stockmarket to an csv file
    '''
    url="https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&outputsize=full&apikey=demo"
    res=requests.get(url)
    if res.status_code==200:
        data=res.json()
        last_refreshed=data["Meta Data"]["3. Last Refreshed"]
        price=data['Time Series (5min)'][last_refreshed]['1. open']
        return price
    else:
        return None

stock_price={}
price=get_stock()
symbol="IBM"
if price is not None:
    stock_price[symbol]=price
print(symbol,price)
# Out:
# IBM 232.5500

# %%
import requests

# Replace 'API_KEY' with your actual API key from NewsAPI
API_KEY = '3805f6bbabcb42b3a0c08a489baf603d'
url = f"https://newsapi.org/v2/top-headlines?country=us&category=business&apiKey={API_KEY}"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
import json
import requests

def fetch_and_print_articles(api_url):
    response = requests.get(api_url)
    
    if response.status_code == 200:
        articles = response.json().get('articles', [])
        
        for index, article in enumerate(articles[:3], start=1):
            print(f"Article {index}:\n{json.dumps(article, sort_keys=True, indent=4)}\n")
    else:
        print(f"Error: {response.status_code}")

API_KEY = '3805f6bbabcb42b3a0c08a489baf603d'
api_endpoint = f"https://newsapi.org/v2/top-headlines?country=us&category=business&apiKey={API_KEY}"

fetch_and_print_articles(api_endpoint)

def jprint(obj):
    print(json.dumps(obj, sort_keys=True, indent=4))

# Example usage:
# jprint(response.json())
# Out:
# Article 1:
# {
#     "author": "Financial Times",
#     "content": null,
#     "description": null,
#     "publishedAt": "2025-04-26T02:01:01Z",
#     "source": {
#         "id": null,
#         "name": "Financial Times"
#     },
#     "title": "Boeing\u2019s return flight highlights America Inc\u2019s exposure to China - Financial Times",
#     "url": "https://www.ft.com/content/6df594e8-92c7-4e11-a796-43e67dc7debc",
#     "urlToImage": null
# }
#
# Article 2:
# {
#     "author": "Emily Wunderlich",
#     "content": "St. Petersburg-Clearwater International Airport was closed for several hours Friday afternoon while law enforcement officials investigated a bomb threat, according to Pinellas County Sheriff Bob Gual\u2026 [+1038 chars]",
#     "description": "An Allegiant plane was evacuated after a flight attendant found a threat on a bathroom door, according to Pinellas County Sheriff Bob Gualtieri.",
#     "publishedAt": "2025-04-25T23:15:03Z",
#     "source": {
# ...

# %%
import requests

# API endpoint and key
API_URL = "https://newsapi.org/v2/top-headlines"
API_KEY = "3805f6bbabcb42b3a0c08a489baf603d"

# Parameters for the API request
params = {
    "country": "us",
    "apiKey": API_KEY
}

# Making the API request
response = requests.get(API_URL, params=params)

# Checking if the request was successful
if response.status_code == 200:
    # Printing the JSON response
    print(response.json())
else:
    print(f"Error: {response.status_code}")
# Out:
# {'status': 'ok', 'totalResults': 35, 'articles': [{'source': {'id': 'the-wall-street-journal', 'name': 'The Wall Street Journal'}, 'author': 'WSJ', 'title': 'The Chinese Satellite Firm Washington Accuses of Helping U.S. Foes - WSJ', 'description': None, 'url': 'https://www.wsj.com/world/china/the-chinese-satellite-firm-washington-accuses-of-helping-u-s-foes-b5e68d2e', 'urlToImage': None, 'publishedAt': '2025-04-26T03:00:00Z', 'content': None}, {'source': {'id': None, 'name': 'Steelers.com'}, 'author': None, 'title': 'How he fits: Kaleb Johnson, RB, Iowa - Steelers.com', 'description': 'Steelers add big, explosive running back to offense', 'url': 'https://www.steelers.com/news/steelers-how-he-fits-kaleb-johnson-rb-iowa', 'urlToImage': 'https://static.clubs.nfl.com/image/upload/t_editorial_landscape_12_desktop/steelers/sitxpggfyp3by8xaqmx4', 'publishedAt': '2025-04-26T02:52:26Z', 'content': None}, {'source': {'id': None, 'name': 'clevelandbrowns.com'}, 'author': None, 'title': 'Browns 
# ...

# %%
import requests

# API endpoint and key
API_URL = "https://newsapi.org/v2/top-headlines"
API_KEY = "3805f6bbabcb42b3a0c08a489baf603d"

# Parameters for the API request
params = {
    "country": "us",
    "apiKey": API_KEY
}

# Making the API request
response = requests.get(API_URL, params=params)

# Checking if the request was successful
if response.status_code == 200:
    # Printing the JSON response
    print(response.json())
else:
    print(f"Error: {response.status_code}")
# Out:
# {'status': 'ok', 'totalResults': 35, 'articles': [{'source': {'id': 'the-wall-street-journal', 'name': 'The Wall Street Journal'}, 'author': 'WSJ', 'title': 'The Chinese Satellite Firm Washington Accuses of Helping U.S. Foes - WSJ', 'description': None, 'url': 'https://www.wsj.com/world/china/the-chinese-satellite-firm-washington-accuses-of-helping-u-s-foes-b5e68d2e', 'urlToImage': None, 'publishedAt': '2025-04-26T03:00:00Z', 'content': None}, {'source': {'id': None, 'name': 'Steelers.com'}, 'author': None, 'title': 'How he fits: Kaleb Johnson, RB, Iowa - Steelers.com', 'description': 'Steelers add big, explosive running back to offense', 'url': 'https://www.steelers.com/news/steelers-how-he-fits-kaleb-johnson-rb-iowa', 'urlToImage': 'https://static.clubs.nfl.com/image/upload/t_editorial_landscape_12_desktop/steelers/sitxpggfyp3by8xaqmx4', 'publishedAt': '2025-04-26T02:52:26Z', 'content': None}, {'source': {'id': None, 'name': 'clevelandbrowns.com'}, 'author': None, 'title': 'Browns 
# ...

# %%
# !pip install geocoder
# Out:
# ...
#    ---------------------------------------- 0.0/98.6 kB ? eta -:--:--
#    ---------------------------------------- 98.6/98.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --------------- ------------------------ 184.3/491.3 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 419.8/491.3 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import json
import turtle
import urllib.request
import time
import webbrowser
import geocoder

# Get the current ISS data
url = "http://api.open-notify.org/astros.json"
response = urllib.request.urlopen(url)
result = json.loads(response.read())

# Save data to a text file
file = open("iss.txt", "w")
file.write("There are currently " +
            str(result["number"]) + " astronauts on the ISS: \n\n")
people = result["people"]

# Save the crew names to the file
for p in people:
    file.write(p['name'] + " - on board" + "\n")

# Get current latitude and longitude
g = geocoder.ip('me')
file.write("\nYour current lat / long is: " + str(g.latlng))
file.close()

# Open the text file in the browser
webbrowser.open("iss.txt")

# Setup the world map in turtle module
screen = turtle.Screen()
screen.setup(1280, 720)
screen.setworldcoordinates(-180, -90, 180, 90)

# Load the world map image
screen.bgpic("images/map.gif")
screen.register_shape("images/iss.gif")
iss = turtle.Turtle()
iss.shape("images/iss.gif")
iss.setheading(45)
iss.penup()

while True:
    # Get the current ISS position in real-time
    url = "http://api.open-notify.org/iss-now.json"
    response = urllib.request.urlopen(url)
    result = json.loads(response.read())

    # Extract the ISS location
    location = result["iss_position"]
    lat = location['latitude']
    lon = location['longitude']

    # Output lon and lat to the terminal
    lat = float(lat)
    lon = float(lon)
    print("\nLatitude: " + str(lat))
    print("\nLongitude: " + str(lon))

    # Update the ISS location on the map
    iss.goto(lon, lat)

    # Refresh every 5 seconds
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[28], line 37
#      34 screen.setworldcoordinates(-180, -90, 180, 90)
#      36 # Load the world map image
# ---> 37 screen.bgpic("images/map.gif")
#      38 screen.register_shape("images/iss.gif")
#      39 iss = turtle.Turtle()
#
# File ~\anaconda3\Lib\turtle.py:1473, in TurtleScreen.bgpic(self, picname)
#    1471     return self._bgpicname
#    1472 if picname not in self._bgpics:
# -> 1473     self._bgpics[picname] = self._image(picname)
#    1474 self._setbgpic(self._bgpic, self._bgpics[picname])
#    1475 self._bgpicname = picname
#
# File ~\anaconda3\Lib\turtle.py:473, in TurtleScreenBase._image(self, filename)
#     469 def _image(self, filename):
#     470     """return an image object containing the
#     471     imagedata from a gif-file named filename.
#     472     """
# ...

# %%
#Example3
#fetching Air Pollution Data through the API provided by the Indian government on data.gov.in

# %%
urlData = requests.get("https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=579b464db66ec23bdd000001cdd3946e44ce4aad7209ff7b23ac571b&format=csv&offset=0&limit=2000").content
#Converting the data to pandas dataframe.
rawData = pd.read_csv(io.StringIO(urlData.decode('utf-8')))
rawData.head()
# Out:
#   country           state           city  \
# 0   India  Andhra_Pradesh     Vijayawada
# 1   India  Andhra_Pradesh     Vijayawada
# 2   India  Andhra_Pradesh     Vijayawada
# 3   India  Andhra_Pradesh  Visakhapatnam
# 4   India  Andhra_Pradesh  Visakhapatnam
#
#                                   station          last_update   latitude  \
# 0   Rajiv Gandhi Park, Vijayawada - APPCB  27-04-2025 10:00:00  16.509717
# 1   Rajiv Gandhi Park, Vijayawada - APPCB  27-04-2025 10:00:00  16.509717
# 2         Rajiv Nagar, Vijayawada - APPCB  27-04-2025 10:00:00  16.554731
# 3  GVM Corporation, Visakhapatnam - APPCB  27-04-2025 10:00:00  17.720000
# 4  GVM Corporation, Visakhapatnam - APPCB  27-04-2025 10:00:00  17.720000
#
#    longitude pollutant_id  pollutant_min  pollutant_max  pollutant_avg
# 0  80.612222          NO2           28.0           45.0           37.0
# 1  80.612222           CO           27.0           31.0           28.0
# ...

# %%
import requests

# %%
import io
import pandas as pd

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        10 non-null     object
#  1   state          10 non-null     object
#  2   city           10 non-null     object
#  3   station        10 non-null     object
#  4   last_update    10 non-null     object
#  5   latitude       10 non-null     float64
#  6   longitude      10 non-null     float64
#  7   pollutant_id   10 non-null     object
#  8   pollutant_min  8 non-null      float64
#  9   pollutant_max  8 non-null      float64
#  10  pollutant_avg  8 non-null      float64
# dtypes: float64(5), object(6)
# memory usage: 1012.0+ bytes

# %%
rawData
# Out:
#   country           state           city  \
# 0   India  Andhra_Pradesh     Vijayawada
# 1   India  Andhra_Pradesh     Vijayawada
# 2   India  Andhra_Pradesh     Vijayawada
# 3   India  Andhra_Pradesh  Visakhapatnam
# 4   India  Andhra_Pradesh  Visakhapatnam
# 5   India  Andhra_Pradesh  Visakhapatnam
# 6   India           Assam       Byrnihat
# 7   India           Bihar           Gaya
# 8   India           Bihar        Katihar
# 9   India           Bihar        Katihar
#
#                                     station          last_update   latitude  \
# 0     Rajiv Gandhi Park, Vijayawada - APPCB  27-04-2025 10:00:00  16.509717
# 1     Rajiv Gandhi Park, Vijayawada - APPCB  27-04-2025 10:00:00  16.509717
# 2           Rajiv Nagar, Vijayawada - APPCB  27-04-2025 10:00:00  16.554731
# 3    GVM Corporation, Visakhapatnam - APPCB  27-04-2025 10:00:00  17.720000
# 4    GVM Corporation, Visakhapatnam - APPCB  27-04-2025 10:00:00  17.720000
# ...
