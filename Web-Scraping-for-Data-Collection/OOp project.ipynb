# %%
import nlpcloud

client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\nlpcloud\__init__.py:185, in Client.entities(self, text, searched_entity)
#     184 try:
# --> 185     r.raise_for_status()
#     186 except HTTPError as err:
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import nlpcloud
#       3 client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
# ----> 4 client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
#
# File ~\anaconda3\Lib\site-packages\nlpcloud\__init__.py:190, in Client.entities(self, text, searched_entity)
#     187     if "<!DOCTYPE html>" in r.text:
#     188         raise HTTPError(str(err))
# --> 190     raise HTTPError(str(err) + ": " + str(r.text))
#     192 return r.json()
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities: Rate limit: maximum number of requests per hour reached. Please contact support to learn how to increase this limit (if you are on the free plan, we encourage you to subscribe to the pay-as-you-go plan which provides a much higher throughput and many free requests). You can change your plan here: https://nlpcloud.com/home/plans.

# %%
pip install nlpcloud
# Out:
# Collecting nlpcloud
#   Downloading nlpcloud-1.1.47-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: requests in c:\users\swaya\anaconda3\lib\site-packages (from nlpcloud) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\swaya\anaconda3\lib\site-packages (from requests->nlpcloud) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\swaya\anaconda3\lib\site-packages (from requests->nlpcloud) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\swaya\anaconda3\lib\site-packages (from requests->nlpcloud) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\swaya\anaconda3\lib\site-packages (from requests->nlpcloud) (2025.1.31)
# Downloading nlpcloud-1.1.47-py3-none-any.whl (3.9 kB)
# Installing collected packages: nlpcloud
# Successfully installed nlpcloud-1.1.47
# Note: you may need to restart the kernel to use updated packages.

# %%
import nlpcloud

class NLPApp:

  def __init__(self):

    self.__database = {}
    self.__first_menu()

  def __first_menu(self):

    first_input = input("""
    Hi! how would you like to proceed?
    1. Not a member? Register
    2. Already a member? Login
    3. Galti se aa gaye? Exit
    """)

    if first_input == '1':
      self.__register()
    elif first_input == '2':
      self.__login()
    else:
      exit()

  def __second_menu(self):

    second_input = input("""
    Hi! how would you like to proceed?
    1. NER
    2. Language Detection
    3. Sentiment Analysis
    4. Logout
    """)

    if second_input == '1':
      self.__ner()
    elif second_input == '2':
      self.__language_detection()
    elif second_input == '3':
      self.__sentiment_analysis()
    else:
      exit()

  def __register(self):
    name = input('enter name')
    email = input('enter email')
    password = input('enter password')

    if email in self.__database:
      print('email already exists')
    else:
      self.__database[email] = [name,password]
      print('registration successful.Now login')
      print(self.__database)
      self.__first_menu()


  def __login(self):
    
    email = input('enter email')
    password = input('enter password')

    if email in self.__database:
      if self.__database[email][1] == password:
        print('login successful')
        self.__second_menu()
      else:
        print('wrong password.Try again')
        self.__login()
    else:
      print('This email is not registered')
      self.__first_menu()

  def __sentiment_analysis(self):
    para = input('enter the paragraph')

    client = nlpcloud.Client("distilbert-base-uncased-emotion", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=False, lang="en")
    response = client.sentiment(para)

    L = []
    for i in response['scored_labels']:
      L.append(i['score'])

    index = sorted(list(enumerate(L)),key=lambda x:x[1],reverse=True)[0][0]

    print(response['scored_labels'][index]['label'])
    self.__second_menu()


obj = NLPApp()
# Out:
#     Hi! how would you like to proceed?
#     1. Not a member? Register
#     2. Already a member? Login
#     3. Galti se aa gaye? Exit
#      1
# enter name swayam
# enter email swayam@gmail.com
# enter password Swayam
# registration successful.Now login
# {'swayam@gmail.com': ['swayam', 'Swayam']}
#     Hi! how would you like to proceed?
#     1. Not a member? Register
#     2. Already a member? Login
#     3. Galti se aa gaye? Exit
#      2
# enter email swayam@gmail.com
# enter password Swayam
# login successful
#     Hi! how would you like to proceed?
#     1. NER
#     2. Language Detection
#     3. Sentiment Analysis
#     4. Logout
#      3
# enter the paragraph This isn't just a beautifully crafted gangster film. Or an outstanding family portrait, for that matter. An amazing period piece. A character study. A lesson in filmmaking and an inspiration to generations of actors, directors, screenwriters and producers. For me, this is more: this is the definitive film. 10 stars out of 10. joy
# joy
#     Hi! how would you like to proceed?
#     1. NER
#     2. Language Detection
#     3. Sentiment Analysis
#     4. Logout
#      3
# enter the paragraph d = {'scored_labels': [{'label': 'sadness', 'score': 0.98093181848526}, {'label': 'joy', 'score': 0.001407247269526124}, {'label': 'love', 'score': 0.0004157320945523679}, {'label': 'anger', 'score': 0.01649504341185093}, {'label': 'fear', 'score': 0.00039679379551671445}, {'label': 'surprise', 'score': 0.00035347335506230593}]}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\nlpcloud\__init__.py:408, in Client.sentiment(self, text, target)
#     407 try:
# --> 408     r.raise_for_status()
#     409 except HTTPError as err:
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/distilbert-base-uncased-emotion/sentiment
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 91
#      87     print(response['scored_labels'][index]['label'])
#      88     self.__second_menu()
# ---> 91 obj = NLPApp()
#
# Cell In[1], line 8, in NLPApp.__init__(self)
#       5 def __init__(self):
#       7   self.__database = {}
# ----> 8   self.__first_menu()
#
# Cell In[1], line 20, in NLPApp.__first_menu(self)
#      12 first_input = input("""
#      13 Hi! how would you like to proceed?
#      14 1. Not a member? Register
#      15 2. Already a member? Login
#      16 3. Galti se aa gaye? Exit
#      17 """)
#      19 if first_input == '1':
# ---> 20   self.__register()
#      21 elif first_input == '2':
#      22   self.__login()
#
# Cell In[1], line 56, in NLPApp.__register(self)
#      54 print('registration successful.Now login')
#      55 print(self.__database)
# ---> 56 self.__first_menu()
#
# Cell In[1], line 22, in NLPApp.__first_menu(self)
#      20   self.__register()
#      21 elif first_input == '2':
# ---> 22   self.__login()
#      23 else:
#      24   exit()
#
# Cell In[1], line 67, in NLPApp.__login(self)
#      65 if self.__database[email][1] == password:
#      66   print('login successful')
# ---> 67   self.__second_menu()
#      68 else:
#      69   print('wrong password.Try again')
#
# Cell In[1], line 41, in NLPApp.__second_menu(self)
#      39   self.__language_detection()
#      40 elif second_input == '3':
# ---> 41   self.__sentiment_analysis()
#      42 else:
#      43   exit()
#
# Cell In[1], line 88, in NLPApp.__sentiment_analysis(self)
#      85 index = sorted(list(enumerate(L)),key=lambda x:x[1],reverse=True)[0][0]
#      87 print(response['scored_labels'][index]['label'])
# ---> 88 self.__second_menu()
#
# Cell In[1], line 41, in NLPApp.__second_menu(self)
#      39   self.__language_detection()
#      40 elif second_input == '3':
# ---> 41   self.__sentiment_analysis()
#      42 else:
#      43   exit()
#
# Cell In[1], line 79, in NLPApp.__sentiment_analysis(self)
#      76 para = input('enter the paragraph')
#      78 client = nlpcloud.Client("distilbert-base-uncased-emotion", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=False, lang="en")
# ---> 79 response = client.sentiment(para)
#      81 L = []
#      82 for i in response['scored_labels']:
#
# File ~\anaconda3\Lib\site-packages\nlpcloud\__init__.py:410, in Client.sentiment(self, text, target)
#     408     r.raise_for_status()
#     409 except HTTPError as err:
# --> 410     raise HTTPError(str(err) + ": " + str(r.text))
#     412 return r.json()
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/distilbert-base-uncased-emotion/sentiment: Rate limit: maximum number of requests per hour reached. Please contact support to learn how to increase this limit (if you are on the free plan, we encourage you to subscribe to the pay-as-you-go plan which provides a much higher throughput and many free requests). You can change your plan here: https://nlpcloud.com/home/plans.

# %%
d = {'scored_labels': [{'label': 'sadness', 'score': 0.98093181848526}, {'label': 'joy', 'score': 0.001407247269526124}, {'label': 'love', 'score': 0.0004157320945523679}, {'label': 'anger', 'score': 0.01649504341185093}, {'label': 'fear', 'score': 0.00039679379551671445}, {'label': 'surprise', 'score': 0.00035347335506230593}]}

# %%
L = []
for i in d['scored_labels']:
  L.append(i['score'])

index = sorted(list(enumerate(L)),key=lambda x:x[1],reverse=True)[0][0]

# %%
d['scored_labels'][index]['label']
# Out:
# 'sadness'

# %%
# !pip install emoji
import emoji
print(emoji.emojize('Python is:grinning_face:'))
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/590.6 kB 653.6 kB/s eta 0:00:01
#    --------------- ------------------------ 225.3/590.6 kB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 471.0/590.6 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 590.6/590.6 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1
# Python is😀
