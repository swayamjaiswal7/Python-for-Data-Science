# %%
#A pandas series is like a column in a table.It is 1-d array holding data

# %%
import pandas as pd

# %%
pd.Series([1,2,3,4,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    4
# dtype: int64

# %%
country=['India','Pakistan','Srilanka','Bangladesh']
pd.Series(country)
# Out:
# 0         India
# 1      Pakistan
# 2      Srilanka
# 3    Bangladesh
# dtype: object

# %%
data=pd.Series([39,38,39,34],index=country,name='Country')
data
# Out:
# India         39
# Pakistan      38
# Srilanka      39
# Bangladesh    34
# Name: Country, dtype: int64

# %%
#series from dictionaries
marks={'Stats1':35,'Stats2':39,'Stats3':29,'Stats4':25}

# %%
marks_series=pd.Series(marks)
type(marks_series)
# Out:
# pandas.core.series.Series

# %%
#Series Attributes
#size
#name
#is_unique

# %%
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name

# %%
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
marks_series.index
# Out:
# Index(['Stats1', 'Stats2', 'Stats3', 'Stats4'], dtype='object')

# %%
pd.Series([1,2,3,4,5,6]).is_unique
# Out:
# True

# %%
runs_series=pd.Series([1,2,3,4,4,5]).index

# %%
runs_series.values
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
marks_series.values
# Out:
# array([35, 39, 29, 25], dtype=int64)

# %% [markdown]
# #### Series using Read_csv

# %%
import pandas as pd

subs = pd.read_csv('subs.csv', index_col=0).squeeze("columns")
type(subs)
# Out:
# pandas.core.frame.DataFrame

# %%
subs
# Out:
# Empty DataFrame
# Columns: []
# Index: [48, 57, 40, 43, 44, 46, 33, 40, 44, 74, 49, 56, 49, 42, 39, 44, 54, 51, 40, 37, 40, 45, 50, 56, 35, 49, 46, 88, 61, 42, 56, 50, 50, 49, 76, 123, 108, 110, 56, 62, 65, 66, 33, 66, 82, 126, 109, 88, 83, 108, 101, 128, 111, 96, 101, 99, 105, 72, 93, 76, 104, 70, 80, 99, 104, 136, 115, 123, 112, 145, 87, 84, 92, 80, 70, 70, 132, 123, 98, 96, 88, 86, 92, 92, 110, 120, 105, 72, 84, 90, 78, 81, 89, 89, 93, 86, 95, 83, 72, 87, ...]
#
# [365 rows x 0 columns]

# %%
vk=pd.read_csv('kohli_ipl.csv')

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
bol=pd.read_csv('bollywood.csv',index_col="movie")

# %%
type(bol)
# Out:
# pandas.core.frame.DataFrame

# %%
bol.sample(10)
# Out:
#                                              lead
# movie
# Taj Mahal: An Eternal Love Story      Zulfi Sayed
# Maximum (film)                          Sonu Sood
# Baaz: A Bird in Danger              Jackie Shroff
# Phamous                           Jimmy Sheirgill
# Shortcut Safari                   Jimmy Sheirgill
# Gone Kesh                            Deepika Amin
# Jodi Breakers                        Bipasha Basu
# Jack and Dil                            Amit Sadh
# Satyameva Jayate (2018 film)         John Abraham
# Raghu Romeo                            Vijay Raaz

# %%
bol['lead']
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
type(bol)
# Out:
# pandas.core.frame.DataFrame

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk.sort_values(by='runs',ascending=False).head(10)
# Out:
#      match_no  runs
# 127       128   113
# 125       126   109
# 122       123   108
# 163       164   100
# 119       120   100
# 81         82    99
# 80         81    93
# 144       145    92
# 177       178    90
# 159       160    84

# %%
vk.plot('runs')
# Out:
# <Axes: xlabel='runs'>
