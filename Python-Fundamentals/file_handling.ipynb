# %%
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# ndslkndklnvlkkvn
# ddlk dldkkc
# kc alkca

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())#removes new line character
# Out:
# ndslkndklnvlkkvn
# ddlk dldkkc
# kc alkca

# %%
with open('example.txt','w') as file:
    file.write('Hello World!\n')
    file.write('This is a new line')
#overwiting

# %%
with open('example.txt','a') as file:
    file.write('Taking place append \n')

# %%
lines=['First line \n']

# %%
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
#new_dir
new_dir='package'
os.mkdir(new_dir)
print(new_dir)
# Out:
# package

# %%
#list files and directory
items=os.listdir('.')
print(items)
# Out:
# ['.ipynb_checkpoints', 'control flow.ipynb', 'destination.txt', 'Dictionaries.ipynb', 'example.csv', 'example.txt', 'file_handling.ipynb', 'functions.ipynb', 'Lists.ipynb', 'loops_practice.ipynb', 'maths.py', 'package', 'Packages_Modules.ipynb', 'PythonTop30.ipynb', 'Python_basics.ipynb', 'Sets.ipynb', 'source.txt', "Strings_and_It'sFunctions.ipynb", 'test_dir', 'Tuple.ipynb', '__init__.py', '__pycache__']

# %%
dir_name='folder'
### join paths
file_name='file.txt'
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name='folder'
### join paths
file_name='file.txt'
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# C:\Users\swaya\Python\folder\file.txt
