# %%
from maths import addition

# %%
addition(a=1,b=2)
# Out:
# 3

# %%
from maths import *

# %%
subtraction(a=1,b=2)
# Out:
# -1

# %%
import array
print(array.array('i',[1,2,3,4,5,6,7]))
# Out:
# array('i', [1, 2, 3, 4, 5, 6, 7])

# %%
import statsmodels as sm

# %%
import random

# %%
print(random.sample(range(10000000), 60))
# Out:
# [4357034, 9230387, 9437921, 6812520, 8309138, 768571, 387719, 3240236, 2437078, 1765845, 4008490, 3003258, 6793448, 1570065, 435124, 4836569, 9519985, 4025014, 3542999, 1661434, 3348023, 4467358, 7889525, 4250971, 3314379, 2619917, 4787841, 8948092, 4098308, 4582679, 5530464, 981945, 4683399, 6567699, 8769666, 8165075, 9623558, 3210535, 1321514, 7436528, 4219791, 2944481, 3966104, 4845733, 8618130, 7689868, 7124349, 9585613, 6235187, 3201604, 797143, 147411, 3629137, 3256555, 2631732, 8619244, 9871655, 3432332, 6179131, 7226403]

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\swaya\\Python'

# %%
os.makedirs('test_dir')

# %%
#high level operations on files
import shutil 
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
#data serialization
#json-csv
import json
data={'name':'swayam','age':22}
json_str=json.dumps(data)

# %%
json_str
# Out:
# '{"name": "swayam", "age": 22}'

# %%
type(json_str)
# Out:
# str

# %%
parsed_data=json.loads(json_str)
print(type(parsed_data))
# Out:
# <class 'dict'>

# %%
import csv
with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Swayam',22])

# %%
with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Swayam', '22']

# %%
from datetime import *

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 4, 23, 17, 14, 21, 342331)

# %%
print(datetime.now()-timedelta(days=1))
# Out:
# 2025-04-22 17:15:35.149400

# %%
import time
print(time.time())
# Out:
# 1745408754.6738877

# %%
time.sleep(2)

# %%
print(time.time())
# Out:
# 1745408776.3359156

# %%
## regular expression
import re

# %%
pattern=r'\d+'
text='there are 123 apples'
match=re.search(pattern,text)

# %%
print(match.group())
# Out:
# 123
