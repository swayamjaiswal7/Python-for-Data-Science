# %%
#variables
a=1

# %%
print(a)
# Out:
# 1

# %%
b=1.2

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 1.2

# %%
x=10
print(x+1)
# Out:
# 11

# %%
x+29+22
# Out:
# 61

# %%
p,q,r=11,12,13 #assigning multiple variables and adding numbers

# %%
p,q,r
# Out:
# (11, 12, 13)

# %%
MyName='swayam' #pascal case

# %%
myName='jaiswal' #camel case

# %%
myname='swayam' #flat case

# %%
my_name='swayam' #snake case

# %%
#variables are case-sensitive
myname='swayam'

# %%
myName
# Out:
# 'jaiswal'

# %%
print('''You're a "good" person''')
# Out:
# You're a "good" person

# %%
print('''You are 'great' ''')
# Out:
# You are 'great'

# %%
#Numeric
#integer 
#float
#complex
#String
#list
#tuple
#dictionary
#Sets
#Boolean

# %%
print("You 're a good man'")
# Out:
# You 're a good man'

# %%
print('''You 're a "good" person ''')
# Out:
# You 're a "good" person

# %%
print("Python is fun")
# Out:
# Python is fun

# %%
print(''' "Quotes" and 'single quotes' can be tricky  ''')
# Out:
#  "Quotes" and 'single quotes' can be tricky

# %%
name='Swayam'
age=22
city='Mumbai'

# %%
print(f" My name is {name} and I am {age} and I am from {city}")
# Out:
#  My name is Swayam and I am 22 and I am from Mumbai

# %%
#Typecasting
A=int(input('Enter Age:'))
# Out:
# Enter Age: 12

# %%
B=str(input('Enter Name'))
# Out:
# Enter Name Swayam

# %%
C=float(input('Enter Salary'))
# Out:
# Enter Salary 120.25

# %%
a=12
b=12.2
c=a+b
print(type(c))
print(a+b)
# Out:
# <class 'float'>
# 24.2

# %%
ind=1001
print(str(ind))
# Out:
# 1001

# %%
bool(0)
# Out:
# False

# %%
#Assignment2
name=str(input("Enter your name"))
stats=float(input("Enter Marks"))
maths=float(input("Enter Marks"))
physics=float(input("Enter Marks"))

percent=((float(stats)+float(maths)+float(physics))/300)*100
print(f"The result of {name} is {int(percent)}%  Well Done")
# Out:
# Enter your name Swayam
# Enter Marks 85
# Enter Marks 75
# Enter Marks 98
# The result of Swayam is 86%  Well Done

# %%
user_data={}
user_data['age']=int(input("enter Age"))
user_data['height']=float(input("Enter height in CM's"))
user_data['status']=str(input("Enter Status"))
print(user_data)
# Out:
# enter Age 22
# Enter height in CM's 175
# Enter Status Adult
# {'age': 22, 'height': 175.0, 'status': 'Adult'}

# %%
#Operators

# %%
print(not(a==10 and b==20))
# Out:
# True

# %%
x=[1,2,3]
y=x
print(x is y)
z=[1,2,3]
print(x is z)#location based assignment
# Out:
# True
# False

# %%
my_list=['apply','orange','watermelon']
print('apply' in my_list)
# Out:
# True

# %%
print('apple' not in my_list)
# Out:
# True

# %%
print('apply' not in my_list)
# Out:
# False

# %%
a=5
b=3
a&b
# Out:
# 1

# %%
a|b
# Out:
# 7

# %%
a^b
# Out:
# 6

# %%
~b
# Out:
# -4

# %%
#conditional statements

# %%
if b>a:
    print('b is greater than a')
else:
    print('a is greater than b')
# Out:
# a is greater than b

# %%
#Nested if and Ternary Operator

# %%
leap=int(input("Enter a year"))

if (leap%4==0 and leap%100!=0) or leap%400==0:
    print(f'{leap} is a leap year')
else:
    print(f"{leap} is not a leap year")
# Out:
# Enter a year 1900
# 1900 is not a leap year

# %%
username="swayam"
password="Swayam1@"

# %%
eusername=str(input("Enter Username"))
epassword=str(input("Enter password"))
    
if eusername==username :
    if password==epassword:
        print("Login successful")
    else:
        print("Incorrect Password")
else:
    print("Login Failed")
# Out:
# Enter Username swayam
# Enter password Swayam1@
# Login successful

# %%
physics=float(input('Physics'))
maths=float(input('Maths'))
stats=float(input('Statistics'))
if ((maths>=65 and physics>=55 and stats>=60) and (maths+physics+stats>=180)) or (maths+physics>=140):
    print("Student is eligible for Msc")
else:
    print("Student is not eligible for Msc")
# Out:
# Physics 45
# Maths 52
# Statistics 33
# Student is not eligible for Msc
