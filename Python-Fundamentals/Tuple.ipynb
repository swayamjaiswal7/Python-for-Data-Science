# %%
tpl=tuple()

# %%
numbers=tuple([1,2,4,5,5,4,3])

# %%
numbers
# Out:
# (1, 2, 4, 5, 5, 4, 3)

# %%
#mixed tuple
mix=(1,'hello',3.23,True)

# %%
#Accessing tuples
numbers[0]
# Out:
# 1

# %%
#Slicing
numbers[1:4]
# Out:
# (2, 4, 5)

# %%
numbers[1:]
# Out:
# (2, 4, 5, 5, 4, 3)

# %%
numbers[-1]
# Out:
# 3

# %%
numbers[::-1]
# Out:
# (3, 4, 5, 5, 4, 2, 1)

# %%
#Operations
concatenation_tuple=numbers+mix

# %%
mix*3
# Out:
# (1, 'hello', 3.23, True, 1, 'hello', 3.23, True, 1, 'hello', 3.23, True)

# %%
mix.count(1)
# Out:
# 2

# %%
mix.index(True)
# Out:
# 0

# %%
a,b,c,d=mix
print(a)
# Out:
# 1

# %%
#Unpacking with stars
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
nested_tuple=((1,2,3),("A","B","C"),(True,False))
print(nested_tuple[0])
print(nested_tuple[0][2])
# Out:
# (1, 2, 3)
# 3

# %%
for sub in nested_tuple:
    for item in sub:
        print(item,end=' ')
    print()
# Out:
# 1 2 3
# A B C
# True False

# %%
tp=(1,1,2,3,4,5,6,7,8,8)
def min_max_sum(tuple):
    sample=()
    a=min(tuple)
    b=max(tuple)
    c=sum(tuple)
    sample=(a,b,c)
    return sample

min_max_sum(tp)
# Out:
# (1, 8, 45)

# %%
s1=set(tp)
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
for i in nested_tuple:
    for item in i:
        print(item,end=" ")
# Out:
# 1 2 3 A B C True False

# %%
tpl_dict={
    (1,2):3,
    (4,5):6,
    (7,8):9
}
print(tpl_dict)
# Out:
# {(1, 2): 3, (4, 5): 6, (7, 8): 9}

# %%
string = "hello"
tpl = tuple(string)
joined_string = ''.join(tpl)
print(joined_string)
# Out:
# hello
